# %% [markdown]
# # Funções e Modularização
#
# Atividades sobre funções, parâmetros, retorno, escopo, decomposição e organização do código.

# %% [markdown]
# ## Regras
#
# - Resolva cada atividade em Python.
# - Escreva a solução na célula abaixo do enunciado.
# - Crie seus próprios testes.
# - Revise nomes, clareza e organização depois que a solução funcionar.

# %% [markdown]
# ## Funções básicas

# %% [markdown]
# ### Atividade 01
#
# Crie uma função que receba dois números e retorne o maior.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 02
#
# Crie uma função que receba três notas e retorne a média.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 03
#
# Crie uma função que receba uma idade e retorne a categoria correspondente.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 04
#
# Crie uma função que receba um número e retorne True se ele for par.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 05
#
# Crie uma função que receba um número e retorne True se ele for primo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 06
#
# Crie uma função que receba uma lista e retorne o maior valor.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 07
#
# Crie uma função que receba uma string e retorne a quantidade de vogais.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 08
#
# Crie uma função que receba uma lista e retorne uma nova lista sem duplicados.

# %%
# Resolva aqui

# %% [markdown]
# ## Parâmetros e retorno

# %% [markdown]
# ### Atividade 09
#
# Crie uma função de cálculo de desconto com percentual padrão.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 10
#
# Crie uma função que receba quantidade variável de notas e retorne a média.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 11
#
# Crie uma função que retorne simultaneamente maior, menor e média de uma lista.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 12
#
# Crie uma função que valide senha e retorne status e mensagem.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 13
#
# Crie uma função que normalize um nome removendo espaços extras.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 14
#
# Crie uma função que receba uma lista e um critério textual para filtrar valores.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 15
#
# Crie uma função que gere uma tabuada como lista de strings.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 16
#
# Crie uma função que receba uma matriz e retorne suas dimensões.

# %%
# Resolva aqui

# %% [markdown]
# ## Decomposição

# %% [markdown]
# ### Atividade 17
#
# Divida um validador de CPF em funções menores.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 18
#
# Divida um sistema de notas em funções de leitura, cálculo e relatório.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 19
#
# Crie funções separadas para cadastrar, listar e buscar itens em uma lista de tarefas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 20
#
# Crie um pequeno menu textual que chame funções diferentes para cada opção.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 21
#
# Crie uma função principal que coordene uma calculadora com operações separadas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 22
#
# Refatore um programa de caixa eletrônico em funções menores.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 23
#
# Crie testes simples para funções usando assert.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 24
#
# Organize funções auxiliares para manipular uma matriz.

# %%
# Resolva aqui
