# %% [markdown]
# # Algoritmos Clássicos
#
# Atividades sobre busca, ordenação, recursão, complexidade e estratégias de resolução.

# %% [markdown]
# ## Regras
#
# - Resolva cada atividade em Python.
# - Escreva a solução na célula abaixo do enunciado.
# - Crie seus próprios testes.
# - Revise nomes, clareza e organização depois que a solução funcionar.

# %% [markdown]
# ## Busca e ordenação

# %% [markdown]
# ### Atividade 01
#
# Implemente busca linear e conte quantas comparações foram feitas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 02
#
# Implemente busca binária em uma lista ordenada.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 03
#
# Implemente ordenação por seleção.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 04
#
# Implemente ordenação por inserção.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 05
#
# Implemente bubble sort.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 06
#
# Compare a quantidade de trocas entre dois algoritmos de ordenação.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 07
#
# Encontre o menor elemento ausente em uma sequência de inteiros positivos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 08
#
# Intercale duas listas ordenadas em uma única lista ordenada.

# %%
# Resolva aqui

# %% [markdown]
# ## Recursão

# %% [markdown]
# ### Atividade 09
#
# Calcule o fatorial de um número usando recursão.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 10
#
# Calcule o n-ésimo termo de Fibonacci usando recursão.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 11
#
# Some os elementos de uma lista usando recursão.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 12
#
# Inverta uma string usando recursão.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 13
#
# Verifique se uma palavra é palíndromo usando recursão.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 14
#
# Calcule a potência de um número usando recursão.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 15
#
# Conte quantos dígitos existem em um número usando recursão.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 16
#
# Resolva a Torre de Hanói para n discos.

# %%
# Resolva aqui

# %% [markdown]
# ## Raciocínio algorítmico

# %% [markdown]
# ### Atividade 17
#
# Resolva o problema de dois números cuja soma resulta em um alvo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 18
#
# Encontre a maior sequência crescente consecutiva em uma lista.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 19
#
# Encontre o maior lucro possível com uma compra e uma venda.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 20
#
# Verifique se uma sequência de parênteses, colchetes e chaves é válida.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 21
#
# Encontre o elemento majoritário de uma lista, se existir.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 22
#
# Calcule o produto dos elementos exceto o próprio índice.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 23
#
# Encontre a maior soma de sublista contígua.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 24
#
# Identifique padrões de complexidade em três soluções diferentes para o mesmo problema.

# %%
# Resolva aqui
