# %% [markdown]
# # Arquivos, Erros e Dados
#
# Atividades sobre leitura e escrita de arquivos, tratamento de exceções, CSV, JSON e organização de dados.

# %% [markdown]
# ## Regras
#
# - Resolva cada atividade em Python.
# - Escreva a solução na célula abaixo do enunciado.
# - Crie seus próprios testes.
# - Revise nomes, clareza e organização depois que a solução funcionar.

# %% [markdown]
# ## Arquivos de texto

# %% [markdown]
# ### Atividade 01
#
# Leia um arquivo de texto e conte quantas linhas ele possui.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 02
#
# Leia um arquivo de texto e conte a frequência de palavras.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 03
#
# Crie um arquivo com uma lista de tarefas digitadas pelo usuário.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 04
#
# Leia um arquivo e exiba apenas as linhas que contêm uma palavra-chave.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 05
#
# Copie o conteúdo de um arquivo para outro removendo linhas vazias.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 06
#
# Crie um relatório de notas em arquivo de texto.

# %%
# Resolva aqui

# %% [markdown]
# ## CSV e JSON

# %% [markdown]
# ### Atividade 07
#
# Leia um CSV de produtos e calcule o valor total em estoque.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 08
#
# Leia um CSV de alunos e gere um resumo de aprovação.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 09
#
# Crie um JSON com dados de contatos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 10
#
# Leia um JSON de tarefas e filtre as tarefas concluídas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 11
#
# Converta dados de uma lista de dicionários para CSV.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 12
#
# Agrupe registros de vendas por mês usando dados lidos de um arquivo.

# %%
# Resolva aqui

# %% [markdown]
# ## Erros e validação

# %% [markdown]
# ### Atividade 13
#
# Trate erro de conversão ao ler números digitados pelo usuário.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 14
#
# Crie uma função de leitura de inteiro que continue pedindo até receber um valor válido.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 15
#
# Trate erro de arquivo inexistente ao tentar abrir um caminho informado.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 16
#
# Valide campos obrigatórios em um cadastro simples.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 17
#
# Crie mensagens de erro claras para entradas inválidas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 18
#
# Monte um fluxo de cadastro que não interrompa o programa quando houver erro.

# %%
# Resolva aqui
