# %% [markdown]
# # Logica de Programacao com Python
#
# Notebook de atividades progressivas para treino de condicionais, loops, strings, listas, matrizes e desafios de raciocinio.
#
# Sem exemplos. Sem gabarito. Apenas problemas.

# %% [markdown]
# ## Regras
#
# - Resolva cada atividade em Python.
# - Use condicionais e loops sempre que fizer sentido.
# - Evite funcoes prontas quando o enunciado pedir raciocinio manual.
# - Mantenha cada solucao na celula logo abaixo do enunciado.
# - Escreva testes proprios quando terminar cada desafio.

# %% [markdown]
# ## Indice
#
# 1. Nivel 1 - Aquecimento
# 2. Nivel 2 - Condicionais Compostas
# 3. Nivel 3 - Loops Basicos
# 4. Nivel 4 - Loops com Decisao
# 5. Nivel 5 - Strings com Loops
# 6. Nivel 6 - Listas e Raciocinio Sequencial
# 7. Nivel 7 - Loops Aninhados
# 8. Nivel 8 - Desafios Integrados
# 9. Nivel 9 - Estilo LeetCode
# 10. Nivel 10 - Desafios Longos

# %% [markdown]
# ## Nivel 1 - Aquecimento

# %% [markdown]
# ### Atividade 01
#
# Crie um programa que leia um numero inteiro e informe se ele e positivo, negativo ou zero.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 02
#
# Crie um programa que leia a idade de uma pessoa e informe sua categoria: crianca, adolescente, adulta ou idosa.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 03
#
# Crie um programa que leia dois numeros e informe qual deles e maior, ou se sao iguais.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 04
#
# Crie um programa que leia uma nota de 0 a 10 e informe se a pessoa foi aprovada, esta em recuperacao ou foi reprovada.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 05
#
# Crie um programa que leia um ano e determine se ele e bissexto.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 06
#
# Crie um programa que leia tres lados e informe se eles formam um triangulo valido.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 07
#
# Crie um programa que leia tres lados de um triangulo valido e classifique como equilatero, isosceles ou escaleno.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 08
#
# Crie um programa que leia uma temperatura e informe uma classificacao: muito frio, frio, agradavel, quente ou muito quente.

# %%
# Resolva aqui

# %% [markdown]
# ## Nivel 2 - Condicionais Compostas

# %% [markdown]
# ### Atividade 09
#
# Crie um programa que leia um horario no formato hora e minuto e informe se ele pertence a madrugada, manha, tarde ou noite.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 10
#
# Crie um programa que leia o valor de uma compra e aplique desconto conforme faixas progressivas definidas por voce.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 11
#
# Crie um programa que leia salario, tempo de empresa e desempenho, e determine se uma pessoa recebe bonus.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 12
#
# Crie um programa que leia peso e altura, calcule o IMC e classifique o resultado.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 13
#
# Crie um programa que leia uma senha e valide se ela atende a criterios minimos de tamanho, numeros e letras.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 14
#
# Crie um programa que simule um caixa eletronico simples, verificando se o saque e possivel com saldo e limite diario.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 15
#
# Crie um programa que leia uma coordenada x, y e informe em qual quadrante ela esta, incluindo eixos e origem.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 16
#
# Crie um programa que leia tres numeros e exiba-os em ordem crescente sem usar funcoes prontas de ordenacao.

# %%
# Resolva aqui

# %% [markdown]
# ## Nivel 3 - Loops Basicos

# %% [markdown]
# ### Atividade 17
#
# Crie um programa que exiba todos os numeros pares de 1 ate 100.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 18
#
# Crie um programa que leia um numero inteiro n e calcule a soma de 1 ate n.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 19
#
# Crie um programa que leia um numero inteiro n e calcule seu fatorial.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 20
#
# Crie um programa que leia varios numeros ate que o usuario digite 0, entao exiba a soma total.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 21
#
# Crie um programa que leia varios numeros ate que o usuario digite um numero negativo, entao exiba a media dos valores validos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 22
#
# Crie um programa que leia um numero inteiro e informe se ele e primo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 23
#
# Crie um programa que exiba os n primeiros termos da sequencia de Fibonacci.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 24
#
# Crie um programa que leia um numero e exiba sua tabuada de 1 a 10.

# %%
# Resolva aqui

# %% [markdown]
# ## Nivel 4 - Loops com Decisao

# %% [markdown]
# ### Atividade 25
#
# Crie um programa que leia 10 numeros e informe quantos sao positivos, negativos e zeros.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 26
#
# Crie um programa que leia n notas e informe a maior, a menor e a media.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 27
#
# Crie um programa que leia uma sequencia de numeros e informe o maior intervalo crescente consecutivo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 28
#
# Crie um programa que leia numeros ate um sentinela e conte quantos sao pares, impares, multiplos de 3 e multiplos de 5.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 29
#
# Crie um programa que calcule a quantidade minima de cedulas para um valor inteiro de saque.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 30
#
# Crie um programa que leia um numero e determine se ele e perfeito.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 31
#
# Crie um programa que leia dois numeros e calcule o MDC usando repeticao.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 32
#
# Crie um programa que leia dois numeros e calcule o MMC usando repeticao.

# %%
# Resolva aqui

# %% [markdown]
# ## Nivel 5 - Strings com Loops

# %% [markdown]
# ### Atividade 33
#
# Crie um programa que leia uma palavra e informe se ela e um palindromo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 34
#
# Crie um programa que conte vogais, consoantes, digitos e outros caracteres em uma frase.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 35
#
# Crie um programa que leia uma frase e conte quantas palavras existem nela sem usar split.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 36
#
# Crie um programa que leia uma string e remova espacos duplicados usando apenas loops e condicionais.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 37
#
# Crie um programa que leia uma string e verifique se todos os parenteses estao balanceados.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 38
#
# Crie um programa que leia duas palavras e informe se uma e anagrama da outra.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 39
#
# Crie um programa que compacte uma string usando contagem de caracteres consecutivos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 40
#
# Crie um programa que encontre o primeiro caractere nao repetido em uma string.

# %%
# Resolva aqui

# %% [markdown]
# ## Nivel 6 - Listas e Raciocinio Sequencial

# %% [markdown]
# ### Atividade 41
#
# Crie um programa que leia n numeros em uma lista e encontre o segundo maior valor sem ordenar.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 42
#
# Crie um programa que leia uma lista e remova valores duplicados preservando a ordem original.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 43
#
# Crie um programa que leia uma lista de numeros e mova todos os zeros para o final preservando a ordem dos demais.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 44
#
# Crie um programa que leia uma lista e informe se ela esta ordenada de forma crescente.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 45
#
# Crie um programa que leia uma lista e encontre a maior soma de dois elementos distintos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 46
#
# Crie um programa que leia uma lista e encontre todos os pares cuja soma seja igual a um alvo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 47
#
# Crie um programa que leia uma lista e encontre a maior sequencia consecutiva crescente.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 48
#
# Crie um programa que leia uma lista binaria e encontre a maior sequencia de 1 consecutivos.

# %%
# Resolva aqui

# %% [markdown]
# ## Nivel 7 - Loops Aninhados

# %% [markdown]
# ### Atividade 49
#
# Crie um programa que desenhe um quadrado de tamanho n usando caracteres.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 50
#
# Crie um programa que desenhe um triangulo alinhado a esquerda com altura n.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 51
#
# Crie um programa que desenhe um triangulo centralizado com altura n.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 52
#
# Crie um programa que gere uma matriz n por n com a diagonal principal marcada.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 53
#
# Crie um programa que gere uma matriz n por n com as duas diagonais marcadas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 54
#
# Crie um programa que leia uma matriz e calcule a soma de cada linha e de cada coluna.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 55
#
# Crie um programa que leia uma matriz quadrada e informe se ela e simetrica.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 56
#
# Crie um programa que simule a multiplicacao de matrizes usando loops aninhados.

# %%
# Resolva aqui

# %% [markdown]
# ## Nivel 8 - Desafios Integrados

# %% [markdown]
# ### Atividade 57
#
# Crie um programa que valide um CPF usando apenas condicionais, loops, listas e operacoes aritmeticas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 58
#
# Crie um programa que converta um numero decimal inteiro para binario sem usar bin.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 59
#
# Crie um programa que converta um numero binario para decimal sem usar conversoes prontas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 60
#
# Crie um programa que implemente busca linear e conte quantas comparacoes foram feitas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 61
#
# Crie um programa que implemente busca binaria em uma lista ordenada e conte as comparacoes.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 62
#
# Crie um programa que implemente ordenacao por selecao.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 63
#
# Crie um programa que implemente ordenacao por insercao.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 64
#
# Crie um programa que implemente uma simulacao de fila de atendimento com chegada, atendimento e saida.

# %%
# Resolva aqui

# %% [markdown]
# ## Nivel 9 - Estilo LeetCode

# %% [markdown]
# ### Atividade 65
#
# Crie uma funcao que receba uma lista de inteiros e um alvo, retornando os indices de dois numeros cuja soma seja igual ao alvo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 66
#
# Crie uma funcao que receba uma string e retorne o tamanho da maior substring sem caracteres repetidos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 67
#
# Crie uma funcao que receba duas listas ordenadas e retorne uma unica lista ordenada.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 68
#
# Crie uma funcao que receba uma lista de precos diarios e retorne o maior lucro possivel com uma compra e uma venda.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 69
#
# Crie uma funcao que receba uma lista e retorne True se existir algum valor duplicado.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 70
#
# Crie uma funcao que receba uma lista de inteiros e retorne o produto de todos os elementos exceto o proprio indice.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 71
#
# Crie uma funcao que receba uma string contendo apenas parenteses, colchetes e chaves, e informe se a sequencia e valida.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 72
#
# Crie uma funcao que receba uma lista e retorne o elemento majoritario, se existir.

# %%
# Resolva aqui

# %% [markdown]
# ## Nivel 10 - Desafios Longos

# %% [markdown]
# ### Atividade 73
#
# Crie um jogo de adivinhacao com tentativas limitadas, historico de palpites e dicas progressivas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 74
#
# Crie um simulador de urna com cadastro de candidatos, votos validos, brancos, nulos e relatorio final.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 75
#
# Crie um sistema de caixa de mercado com cadastro de produtos, carrinho, descontos condicionais e totalizacao.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 76
#
# Crie um analisador de desempenho de turma com notas, faltas, ranking, recuperacao e relatorio final.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 77
#
# Crie um validador de labirinto em matriz que determine se existe caminho entre entrada e saida.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 78
#
# Crie uma simulacao de batalha em turnos com vida, ataque, defesa, itens e criterio de fim de jogo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 79
#
# Crie um compactador simples de texto por frequencia de caracteres e reconstrua o texto original.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 80
#
# Crie um interpretador simples de comandos de texto para manipular uma lista de tarefas.

# %%
# Resolva aqui
