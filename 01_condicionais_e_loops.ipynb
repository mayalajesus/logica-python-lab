# %% [markdown]
# # Lógica de Programação com Python
#
# Notebook de atividades progressivas para praticar condicionais, laços de repetição, strings, listas, matrizes e raciocínio algorítmico.

# %% [markdown]
# ## Regras
#
# - Resolva cada atividade em Python.
# - Use condicionais e laços de repetição sempre que fizer sentido.
# - Evite funções prontas quando o enunciado pedir raciocínio manual.
# - Mantenha cada solução na célula logo abaixo do enunciado.
# - Escreva testes próprios quando terminar cada desafio.

# %% [markdown]
# ## Índice
#
# 1. Nível 1 - Aquecimento
# 2. Nível 2 - Condicionais compostas
# 3. Nível 3 - Laços básicos
# 4. Nível 4 - Laços com decisão
# 5. Nível 5 - Strings com laços
# 6. Nível 6 - Listas e raciocínio sequencial
# 7. Nível 7 - Laços aninhados
# 8. Nível 8 - Desafios integrados
# 9. Nível 9 - Estilo LeetCode
# 10. Nível 10 - Desafios longos

# %% [markdown]
# ## Nível 1 - Aquecimento

# %% [markdown]
# ### Atividade 01
#
# Crie um programa que leia um número inteiro e informe se ele é positivo, negativo ou zero.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 02
#
# Crie um programa que leia a idade de uma pessoa e informe sua categoria: criança, adolescente, adulta ou idosa.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 03
#
# Crie um programa que leia dois números e informe qual deles é maior, ou se são iguais.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 04
#
# Crie um programa que leia uma nota de 0 a 10 e informe se a pessoa foi aprovada, está em recuperação ou foi reprovada.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 05
#
# Crie um programa que leia um ano e determine se ele é bissexto.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 06
#
# Crie um programa que leia três lados e informe se eles formam um triângulo válido.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 07
#
# Crie um programa que leia três lados de um triângulo válido e classifique-o como equilátero, isósceles ou escaleno.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 08
#
# Crie um programa que leia uma temperatura e informe uma classificação: muito frio, frio, agradável, quente ou muito quente.

# %%
# Resolva aqui

# %% [markdown]
# ## Nível 2 - Condicionais compostas

# %% [markdown]
# ### Atividade 09
#
# Crie um programa que leia um horário no formato hora e minuto e informe se ele pertence à madrugada, manhã, tarde ou noite.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 10
#
# Crie um programa que leia o valor de uma compra e aplique desconto conforme faixas progressivas definidas por você.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 11
#
# Crie um programa que leia salário, tempo de empresa e desempenho, e determine se uma pessoa recebe bônus.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 12
#
# Crie um programa que leia peso e altura, calcule o IMC e classifique o resultado.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 13
#
# Crie um programa que leia uma senha e valide se ela atende a critérios mínimos de tamanho, números e letras.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 14
#
# Crie um programa que simule um caixa eletrônico simples, verificando se o saque é possível com saldo e limite diário.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 15
#
# Crie um programa que leia uma coordenada x, y e informe em qual quadrante ela está, incluindo eixos e origem.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 16
#
# Crie um programa que leia três números e exiba-os em ordem crescente sem usar funções prontas de ordenação.

# %%
# Resolva aqui

# %% [markdown]
# ## Nível 3 - Laços básicos

# %% [markdown]
# ### Atividade 17
#
# Crie um programa que exiba todos os números pares de 1 até 100.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 18
#
# Crie um programa que leia um número inteiro n e calcule a soma de 1 até n.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 19
#
# Crie um programa que leia um número inteiro n e calcule seu fatorial.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 20
#
# Crie um programa que leia vários números até que o usuário digite 0. Em seguida, exiba a soma total.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 21
#
# Crie um programa que leia vários números até que o usuário digite um número negativo. Em seguida, exiba a média dos valores válidos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 22
#
# Crie um programa que leia um número inteiro e informe se ele é primo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 23
#
# Crie um programa que exiba os n primeiros termos da sequência de Fibonacci.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 24
#
# Crie um programa que leia um número e exiba sua tabuada de 1 a 10.

# %%
# Resolva aqui

# %% [markdown]
# ## Nível 4 - Laços com decisão

# %% [markdown]
# ### Atividade 25
#
# Crie um programa que leia 10 números e informe quantos são positivos, negativos e zeros.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 26
#
# Crie um programa que leia n notas e informe a maior, a menor e a média.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 27
#
# Crie um programa que leia uma sequência de números e informe o maior intervalo crescente consecutivo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 28
#
# Crie um programa que leia números até um valor sentinela e conte quantos são pares, ímpares, múltiplos de 3 e múltiplos de 5.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 29
#
# Crie um programa que calcule a quantidade mínima de cédulas para um valor inteiro de saque.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 30
#
# Crie um programa que leia um número e determine se ele é perfeito.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 31
#
# Crie um programa que leia dois números e calcule o MDC usando repetição.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 32
#
# Crie um programa que leia dois números e calcule o MMC usando repetição.

# %%
# Resolva aqui

# %% [markdown]
# ## Nível 5 - Strings com laços

# %% [markdown]
# ### Atividade 33
#
# Crie um programa que leia uma palavra e informe se ela é um palíndromo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 34
#
# Crie um programa que conte vogais, consoantes, dígitos e outros caracteres em uma frase.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 35
#
# Crie um programa que leia uma frase e conte quantas palavras existem nela sem usar split.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 36
#
# Crie um programa que leia uma string e remova espaços duplicados usando apenas laços e condicionais.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 37
#
# Crie um programa que leia uma string e verifique se todos os parênteses estão balanceados.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 38
#
# Crie um programa que leia duas palavras e informe se uma é anagrama da outra.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 39
#
# Crie um programa que compacte uma string usando contagem de caracteres consecutivos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 40
#
# Crie um programa que encontre o primeiro caractere não repetido em uma string.

# %%
# Resolva aqui

# %% [markdown]
# ## Nível 6 - Listas e raciocínio sequencial

# %% [markdown]
# ### Atividade 41
#
# Crie um programa que leia n números em uma lista e encontre o segundo maior valor sem ordenar.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 42
#
# Crie um programa que leia uma lista e remova valores duplicados preservando a ordem original.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 43
#
# Crie um programa que leia uma lista de números e mova todos os zeros para o final preservando a ordem dos demais.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 44
#
# Crie um programa que leia uma lista e informe se ela está ordenada de forma crescente.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 45
#
# Crie um programa que leia uma lista e encontre a maior soma de dois elementos distintos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 46
#
# Crie um programa que leia uma lista e encontre todos os pares cuja soma seja igual a um alvo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 47
#
# Crie um programa que leia uma lista e encontre a maior sequência consecutiva crescente.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 48
#
# Crie um programa que leia uma lista binária e encontre a maior sequência de 1 consecutivos.

# %%
# Resolva aqui

# %% [markdown]
# ## Nível 7 - Laços aninhados

# %% [markdown]
# ### Atividade 49
#
# Crie um programa que desenhe um quadrado de tamanho n usando caracteres.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 50
#
# Crie um programa que desenhe um triângulo alinhado à esquerda com altura n.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 51
#
# Crie um programa que desenhe um triângulo centralizado com altura n.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 52
#
# Crie um programa que gere uma matriz n por n com a diagonal principal marcada.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 53
#
# Crie um programa que gere uma matriz n por n com as duas diagonais marcadas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 54
#
# Crie um programa que leia uma matriz e calcule a soma de cada linha e de cada coluna.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 55
#
# Crie um programa que leia uma matriz quadrada e informe se ela é simétrica.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 56
#
# Crie um programa que simule a multiplicação de matrizes usando laços aninhados.

# %%
# Resolva aqui

# %% [markdown]
# ## Nível 8 - Desafios integrados

# %% [markdown]
# ### Atividade 57
#
# Crie um programa que valide um CPF usando apenas condicionais, laços, listas e operações aritméticas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 58
#
# Crie um programa que converta um número decimal inteiro para binário sem usar bin.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 59
#
# Crie um programa que converta um número binário para decimal sem usar conversões prontas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 60
#
# Crie um programa que implemente busca linear e conte quantas comparações foram feitas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 61
#
# Crie um programa que implemente busca binária em uma lista ordenada e conte as comparações.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 62
#
# Crie um programa que implemente ordenação por seleção.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 63
#
# Crie um programa que implemente ordenação por inserção.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 64
#
# Crie um programa que implemente uma simulação de fila de atendimento com chegada, atendimento e saída.

# %%
# Resolva aqui

# %% [markdown]
# ## Nível 9 - Estilo LeetCode

# %% [markdown]
# ### Atividade 65
#
# Crie uma função que receba uma lista de inteiros e um alvo, retornando os índices de dois números cuja soma seja igual ao alvo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 66
#
# Crie uma função que receba uma string e retorne o tamanho da maior substring sem caracteres repetidos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 67
#
# Crie uma função que receba duas listas ordenadas e retorne uma única lista ordenada.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 68
#
# Crie uma função que receba uma lista de preços diários e retorne o maior lucro possível com uma compra e uma venda.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 69
#
# Crie uma função que receba uma lista e retorne True se existir algum valor duplicado.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 70
#
# Crie uma função que receba uma lista de inteiros e retorne o produto de todos os elementos exceto o próprio índice.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 71
#
# Crie uma função que receba uma string contendo apenas parênteses, colchetes e chaves, e informe se a sequência é válida.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 72
#
# Crie uma função que receba uma lista e retorne o elemento majoritário, se existir.

# %%
# Resolva aqui

# %% [markdown]
# ## Nível 10 - Desafios longos

# %% [markdown]
# ### Atividade 73
#
# Crie um jogo de adivinhação com tentativas limitadas, histórico de palpites e dicas progressivas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 74
#
# Crie um simulador de urna com cadastro de candidatos, votos válidos, brancos, nulos e relatório final.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 75
#
# Crie um sistema de caixa de mercado com cadastro de produtos, carrinho, descontos condicionais e totalização.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 76
#
# Crie um analisador de desempenho de turma com notas, faltas, ranking, recuperação e relatório final.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 77
#
# Crie um validador de labirinto em matriz que determine se existe caminho entre entrada e saída.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 78
#
# Crie uma simulação de batalha em turnos com vida, ataque, defesa, itens e critério de fim de jogo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 79
#
# Crie um compactador simples de texto por frequência de caracteres e reconstrua o texto original.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 80
#
# Crie um interpretador simples de comandos de texto para manipular uma lista de tarefas.

# %%
# Resolva aqui
