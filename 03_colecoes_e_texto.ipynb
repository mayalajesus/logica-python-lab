# %% [markdown]
# # Coleções e Texto
#
# Atividades sobre strings, listas, tuplas, conjuntos, dicionários e matrizes.

# %% [markdown]
# ## Regras
#
# - Resolva cada atividade em Python.
# - Escreva a solução na célula abaixo do enunciado.
# - Crie seus próprios testes.
# - Revise nomes, clareza e organização depois que a solução funcionar.

# %% [markdown]
# ## Strings

# %% [markdown]
# ### Atividade 01
#
# Leia uma palavra e informe se ela é um palíndromo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 02
#
# Conte vogais, consoantes, dígitos e outros caracteres em uma frase.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 03
#
# Leia uma frase e conte quantas palavras existem nela sem usar split.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 04
#
# Remova espaços duplicados de uma string usando laços e condicionais.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 05
#
# Verifique se todos os parênteses de uma string estão balanceados.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 06
#
# Leia duas palavras e informe se uma é anagrama da outra.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 07
#
# Compacte uma string usando contagem de caracteres consecutivos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 08
#
# Encontre o primeiro caractere não repetido em uma string.

# %%
# Resolva aqui

# %% [markdown]
# ## Listas, tuplas e conjuntos

# %% [markdown]
# ### Atividade 09
#
# Leia n números em uma lista e encontre o segundo maior valor sem ordenar.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 10
#
# Remova valores duplicados de uma lista preservando a ordem original.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 11
#
# Mova todos os zeros para o final de uma lista preservando a ordem dos demais.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 12
#
# Informe se uma lista está ordenada de forma crescente.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 13
#
# Encontre todos os pares de uma lista cuja soma seja igual a um alvo.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 14
#
# Calcule a interseção entre duas listas sem usar operador de conjunto.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 15
#
# Crie uma tupla com dados de produtos e filtre os produtos acima de um preço informado.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 16
#
# Use conjuntos para identificar elementos presentes em uma lista e ausentes em outra.

# %%
# Resolva aqui

# %% [markdown]
# ## Dicionários e matrizes

# %% [markdown]
# ### Atividade 17
#
# Conte a frequência de cada palavra em uma frase usando dicionário.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 18
#
# Crie um cadastro simples de alunos com nome, nota e situação.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 19
#
# Agrupe vendas por categoria usando dicionário.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 20
#
# Leia uma matriz e calcule a soma de cada linha e de cada coluna.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 21
#
# Informe se uma matriz quadrada é simétrica.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 22
#
# Gere uma matriz identidade de ordem n.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 23
#
# Faça a transposição de uma matriz.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 24
#
# Simule a multiplicação de matrizes usando laços aninhados.

# %%
# Resolva aqui
