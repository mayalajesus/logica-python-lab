# %% [markdown]
# # Desafios Integrados
#
# Atividades maiores que combinam vários assuntos de lógica de programação.

# %% [markdown]
# ## Regras
#
# - Resolva cada atividade em Python.
# - Escreva a solução na célula abaixo do enunciado.
# - Crie seus próprios testes.
# - Revise nomes, clareza e organização depois que a solução funcionar.

# %% [markdown]
# ## Mini-sistemas

# %% [markdown]
# ### Atividade 01
#
# Crie um sistema de tarefas com cadastro, listagem, busca, conclusão e remoção.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 02
#
# Crie um sistema de biblioteca com livros, empréstimos e devoluções.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 03
#
# Crie um sistema de caixa de mercado com produtos, carrinho, descontos e totalização.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 04
#
# Crie um simulador de urna com candidatos, votos válidos, brancos, nulos e relatório.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 05
#
# Crie um analisador de desempenho de turma com notas, faltas, ranking e recuperação.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 06
#
# Crie uma agenda de contatos com busca por nome, telefone e cidade.

# %%
# Resolva aqui

# %% [markdown]
# ## Jogos e simulações

# %% [markdown]
# ### Atividade 07
#
# Crie um jogo de adivinhação com tentativas limitadas e histórico de palpites.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 08
#
# Crie um jogo da velha com validação de jogadas e verificação de vencedor.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 09
#
# Crie uma simulação de batalha em turnos com vida, ataque, defesa e itens.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 10
#
# Crie um validador de labirinto em matriz que determine se existe caminho entre entrada e saída.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 11
#
# Crie um simulador de fila de atendimento com chegada, atendimento e saída.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 12
#
# Crie uma simulação de caixa eletrônico com saldo, extrato, saque e depósito.

# %%
# Resolva aqui

# %% [markdown]
# ## Projetos de raciocínio

# %% [markdown]
# ### Atividade 13
#
# Crie um validador de CPF usando funções, listas e operações aritméticas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 14
#
# Crie um compactador simples de texto e reconstrua o texto original.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 15
#
# Crie um interpretador simples de comandos para manipular uma lista de tarefas.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 16
#
# Crie um resolvedor de sudoku parcial que valide linhas, colunas e blocos.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 17
#
# Crie um analisador de logs que agrupe eventos por tipo e horário.

# %%
# Resolva aqui

# %% [markdown]
# ### Atividade 18
#
# Crie um programa que compare duas estratégias de solução para o mesmo problema.

# %%
# Resolva aqui
